# %%
import spacy
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
nlp = spacy.load('en_core_web_sm')

# %%
data_raw = pd.read_csv('train_50k.csv')

# %%
data_raw.head()
# Out:
#                 id                                              title  \
# 0  pubmed23n0001_0  [Biochemical studies on camomile components/II...
# 1  pubmed23n0001_1  [Demonstration of tumor inhibiting properties ...
# 2  pubmed23n0001_2  Effect of etafenone on total and regional myoc...
# 3  pubmed23n0001_3  Influence of a new virostatic compound on the ...
# 4  pubmed23n0001_4  Pharmacological properties of new neuroleptic ...
#
#                                              content  \
# 0  (--)-alpha-Bisabolol has a primary antipeptic ...
# 1  A report is given on the recent discovery of o...
# 2  The distribution of blood flow to the subendoc...
# 3  The virostatic compound N,N-diethyl-4-[2-(2-ox...
# 4  RMI 61 140, RMI 61 144 and RMI 61 280 are newl...
#
#                                             contents  PMID
# 0  [Biochemical studies on camomile components/II...    21
# 1  [Demonstration of tumor inhibiting properties ...    22
# 2  Effect of etafenone on total and regional myoc...    23
# 3  Influence of a new virostatic compound on the ...    24
# 4  Pharmacological properties of new neuroleptic ...    25

# %%
data_raw.shape
# Out:
# (50000, 5)

# %%
data_raw.isnull().sum()
# Out:
# id          0
# title       0
# content     0
# contents    0
# PMID        0
# dtype: int64

# %%
data_raw = data_raw.drop(['id', 'title', 'content'], axis=1)

# %%
data_raw.head()
# Out:
#                                             contents  PMID
# 0  [Biochemical studies on camomile components/II...    21
# 1  [Demonstration of tumor inhibiting properties ...    22
# 2  Effect of etafenone on total and regional myoc...    23
# 3  Influence of a new virostatic compound on the ...    24
# 4  Pharmacological properties of new neuroleptic ...    25

# %%
data_raw.iloc[0]['contents']
# Out:
# "[Biochemical studies on camomile components/III. In vitro studies about the antipeptic activity of (--)-alpha-bisabolol (author's transl)]. (--)-alpha-Bisabolol has a primary antipeptic action depending on dosage, which is not caused by an alteration of the pH-value. The proteolytic activity of pepsin is reduced by 50 percent through addition of bisabolol in the ratio of 1/0.5. The antipeptic action of bisabolol only occurs in case of direct contact. In case of a previous contact with the substrate, the inhibiting effect is lost."

# %%
doc = nlp(data_raw.iloc[0]['contents'])

# %%
data_raw['contents'].apply(lambda x: len(x.split(' '))).plot(kind='hist', bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
def token_to_df(doc=doc):
    token_info = []
    for token in doc:
        token_info.append({
            "Text": token.text,
            "Index": token.idx,
            "Whitespace": token.is_space,
            "Is Alphanumeric?": token.is_alpha,
            "Is Punctuation?": token.is_punct,
            "Is Stop Word?": token.is_stop
        })
    return pd.DataFrame(token_info)

token_to_df(doc)
# Out:
#             Text  Index  Whitespace  Is Alphanumeric?  Is Punctuation?  \
# 0              [      0       False             False             True
# 1    Biochemical      1       False              True            False
# 2        studies     13       False              True            False
# 3             on     21       False              True            False
# 4       camomile     24       False              True            False
# ..           ...    ...         ...               ...              ...
# 98    inhibiting    509       False              True            False
# 99        effect    520       False              True            False
# 100           is    527       False              True            False
# 101         lost    530       False              True            False
# 102            .    534       False             False             True
#
#      Is Stop Word?
# 0            False
# 1            False
# 2            False
# 3             True
# 4            False
# ..             ...
# 98           False
# 99           False
# 100           True
# 101          False
# 102          False
#
# [103 rows x 6 columns]

# %%
def clean_text(text):
    complete_doc = nlp(text)
    words = [token.text for token in complete_doc 
             if token.is_alpha and not token.is_stop and not token.is_punct]
    return ' '.join(words)

def lemmalize_text(text):
    complete_doc = nlp(text)
    words = [token.lemma_ for token in complete_doc]
    return ' '.join(words)

# %%
text = data_raw.iloc[0]['contents']
text = clean_text(text)
text = lemmalize_text(text)
clean_doc = nlp(text)

# %%
token_to_df(clean_doc)
# Out:
#            Text  Index  Whitespace  Is Alphanumeric?  Is Punctuation?  \
# 0   biochemical      0       False              True            False
# 1         study     12       False              True            False
# 2      camomile     18       False              True            False
# 3     component     27       False              True            False
# 4           iii     37       False              True            False
# 5         vitro     41       False              True            False
# 6         study     47       False              True            False
# 7    antipeptic     53       False              True            False
# 8      activity     64       False              True            False
# 9     bisabolol     73       False              True            False
# 10       author     83       False              True            False
# 11       transl     90       False              True            False
# 12    Bisabolol     97       False              True            False
# 13      primary    107       False              True            False
# 14   antipeptic    115       False              True            False
# 15       action    126       False              True            False
# 16       depend    133       False              True            False
# 17       dosage    140       False              True            False
# 18        cause    147       False              True            False
# 19   alteration    153       False              True            False
# 20           ph    164       False              True            False
# 21        value    167       False              True            False
# 22  proteolytic    173       False              True            False
# 23     activity    185       False              True            False
# 24       pepsin    194       False              True            False
# 25       reduce    201       False              True            False
# 26      percent    208       False              True            False
# 27     addition    216       False              True            False
# 28    bisabolol    225       False              True            False
# 29        ratio    235       False              True            False
# 30   antipeptic    241       False              True            False
# 31       action    252       False              True            False
# 32    bisabolol    259       False              True            False
# 33        occur    269       False              True            False
# 34         case    275       False              True            False
# 35       direct    280       False              True            False
# 36      contact    287       False              True            False
# 37         case    295       False              True            False
# 38     previous    300       False              True            False
# 39      contact    309       False              True            False
# 40    substrate    317       False              True            False
# 41      inhibit    327       False              True            False
# 42       effect    335       False              True            False
# 43         lose    342       False              True            False
#
#     Is Stop Word?
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False
# 8           False
# 9           False
# 10          False
# 11          False
# 12          False
# 13          False
# 14          False
# 15          False
# 16          False
# 17          False
# 18          False
# 19          False
# 20          False
# 21          False
# 22          False
# 23          False
# 24          False
# 25          False
# 26          False
# 27          False
# 28          False
# 29          False
# 30          False
# 31          False
# 32          False
# 33          False
# 34          False
# 35          False
# 36          False
# 37          False
# 38          False
# 39          False
# 40          False
# 41          False
# 42          False
# 43          False

# %%
for token in doc:
    if str(token) != str(token.lemma_):
        print(f"{str(token):>20} : {str(token.lemma_)}")
# Out:
#          Biochemical : biochemical
#              studies : study
#           components : component
#                   In : in
#              studies : study
#                  has : have
#            depending : depend
#                   is : be
#               caused : cause
#                   pH : ph
#                  The : the
#                   is : be
#              reduced : reduce
#                  The : the
#               occurs : occur
#                   In : in
#           inhibiting : inhibit
#                   is : be
#                 lost : lose

# %%
def words_frequency(text):
    complete_doc = nlp(text)
    words = [token.text for token in complete_doc]
    return Counter(words)

# %%
words_frequency(text)
# Out:
# Counter({'antipeptic': 3,
#          'bisabolol': 3,
#          'study': 2,
#          'activity': 2,
#          'action': 2,
#          'case': 2,
#          'contact': 2,
#          'biochemical': 1,
#          'camomile': 1,
#          'component': 1,
#          'iii': 1,
#          'vitro': 1,
#          'author': 1,
#          'transl': 1,
#          'Bisabolol': 1,
#          'primary': 1,
#          'depend': 1,
#          'dosage': 1,
#          'cause': 1,
#          'alteration': 1,
#          'ph': 1,
#          'value': 1,
#          'proteolytic': 1,
#          'pepsin': 1,
#          'reduce': 1,
#          'percent': 1,
#          'addition': 1,
#          'ratio': 1,
#          'occur': 1,
#          'direct': 1,
#          'previous': 1,
#          'substrate': 1,
#          'inhibit': 1,
#          'effect': 1,
#          'lose': 1})

# %%
def tokenized_text(text):
    complete_doc = nlp(text)
    words = [token.text.lower() for token in complete_doc]
    return words

# %%
clean = data_raw.loc[:, 'contents'].apply(clean_text).apply(lemmalize_text).apply(tokenized_text)
clean
# Out:
# 0        [biochemical, study, camomile, component, iii,...
# 1        [demonstration, tumor, inhibit, property, stro...
# 2        [effect, etafenone, total, regional, myocardia...
# 3        [influence, new, virostatic, compound, inducti...
# 4        [pharmacological, property, new, neuroleptic, ...
#                                ...
# 49995    [interaction, bacterial, membrane, peptidolipi...
# 49996    [study, membrane, bind, solubilize, ribonucleo...
# 49997    [interaction, l, ascorbic, acid, active, cente...
# 49998    [biosynthesis, streptomycin, dtdp, dihydrostre...
# 49999    [purification, property, valyl, trna, syntheta...
# Name: contents, Length: 50000, dtype: object

# %%
clean.apply(lambda x: len(x)).plot(kind='hist', bins=50)
# Out:
# <Axes: ylabel='Frequency'>
